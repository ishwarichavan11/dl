# %%
import numpy as np
import pandas as pd
import os

# %%
testing_letter = pd.read_csv('emnist-letters-test.csv')
training_letter = pd.read_csv('emnist-letters-train.csv')

# %%
print(training_letter.shape)
print(testing_letter.shape)
# Out:
# (88799, 785)
# (14799, 785)

# %%
y1 = np.array(training_letter.iloc[:,0].values)
x1 = np.array(training_letter.iloc[:,1:].values)

y2 = np.array(testing_letter.iloc[:,0].values)
x2 = np.array(testing_letter.iloc[:,1:].values)
print(y1.shape)
print(x1.shape)
# Out:
# (88799,)
# (88799, 784)

# %%
import matplotlib.pyplot as plt 
fig,axes = plt.subplots(3,5,figsize=(10,8))
for i,ax in enumerate(axes.flat):
    ax.imshow(x1[i].reshape([28,28]))

# %%
import tensorflow as tf

# %%
train_images = x1 / 255.0
test_images = x2 / 255.0

train_images_number = train_images.shape[0]
train_images_height = 28
train_images_width = 28
train_images_size = train_images_height*train_images_width

train_images = train_images.reshape(train_images_number, train_images_height, train_images_width, 1)

test_images_number = test_images.shape[0]
test_images_height = 28
test_images_width = 28
test_images_size = test_images_height*test_images_width

test_images = test_images.reshape(test_images_number, test_images_height, test_images_width, 1)

# %%
number_of_classes = 37

y1 = tf.keras.utils.to_categorical(y1, number_of_classes)
y2 = tf.keras.utils.to_categorical(y2, number_of_classes)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y = train_test_split(train_images,y1,test_size=0.2,random_state = 42)

# %%
model = tf.keras.Sequential([ 
    tf.keras.layers.Conv2D(32,3,input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(number_of_classes,activation='softmax')
])

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
MCP = ModelCheckpoint('Best_points.h5',verbose=1,save_best_only=True,monitor='val_accuracy',mode='max')
ES = EarlyStopping(monitor='val_accuracy',min_delta=0,verbose=0,restore_best_weights = True,patience=3,mode='max')
RLP = ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.2,min_lr=0.0001)

# %%
history = model.fit(train_x,train_y,epochs=10,validation_data=(test_x,test_y),callbacks=[MCP,ES,RLP])
# Out:
# Epoch 1/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.5463 - accuracy: 0.8291
# Epoch 1: val_accuracy improved from -inf to 0.88885, saving model to Best_points.h5
# 2220/2220 [==============================] - 126s 56ms/step - loss: 0.5463 - accuracy: 0.8291 - val_loss: 0.3465 - val_accuracy: 0.8889 - lr: 0.0010
# Epoch 2/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.2830 - accuracy: 0.9083
# Epoch 2: val_accuracy improved from 0.88885 to 0.89713, saving model to Best_points.h5
# 2220/2220 [==============================] - 123s 56ms/step - loss: 0.2830 - accuracy: 0.9083 - val_loss: 0.3271 - val_accuracy: 0.8971 - lr: 0.0010
# Epoch 3/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.2214 - accuracy: 0.9281
# Epoch 3: val_accuracy improved from 0.89713 to 0.90113, saving model to Best_points.h5
# 2220/2220 [==============================] - 129s 58ms/step - loss: 0.2214 - accuracy: 0.9281 - val_loss: 0.3469 - val_accuracy: 0.9011 - lr: 0.0010
# Epoch 4/10
# 2219/2220 [============================>.] - ETA: 0s - loss: 0.1928 - accuracy: 0.9357
# Epoch 4: val_accuracy did not improve from 0.90113
# 2220/2220 [==============================] - 129s 58ms/step - loss: 0.1928 - accuracy: 0.9357 - val_loss: 0.3477 - val_accuracy: 0.8953 - lr: 0.0010
# Epoch 5/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.1790 - accuracy: 0.9403
# Epoch 5: val_accuracy did not improve from 0.90113
# 2220/2220 [==============================] - 127s 57ms/step - loss: 0.1790 - accuracy: 0.9403 - val_loss: 0.4200 - val_accuracy: 0.8967 - lr: 0.0010
# Epoch 6/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9688
# Epoch 6: val_accuracy improved from 0.90113 to 0.91723, saving model to Best_points.h5
# 2220/2220 [==============================] - 128s 58ms/step - loss: 0.0850 - accuracy: 0.9688 - val_loss: 0.3945 - val_accuracy: 0.9172 - lr: 2.0000e-04
# Epoch 7/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9735
# Epoch 7: val_accuracy did not improve from 0.91723
# 2220/2220 [==============================] - 133s 60ms/step - loss: 0.0692 - accuracy: 0.9735 - val_loss: 0.3685 - val_accuracy: 0.9151 - lr: 2.0000e-04
# Epoch 8/10
# 2219/2220 [============================>.] - ETA: 0s - loss: 0.0638 - accuracy: 0.9756
# Epoch 8: val_accuracy did not improve from 0.91723
# 2220/2220 [==============================] - 117s 53ms/step - loss: 0.0638 - accuracy: 0.9756 - val_loss: 0.4293 - val_accuracy: 0.9164 - lr: 2.0000e-04
# Epoch 9/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9797
# Epoch 9: val_accuracy did not improve from 0.91723
# 2220/2220 [==============================] - 111s 50ms/step - loss: 0.0528 - accuracy: 0.9797 - val_loss: 0.4029 - val_accuracy: 0.9168 - lr: 1.0000e-04

# %%
import seaborn as sns

# %%
q = len(history.history['accuracy'])

plt.figsize=(10,10)
sns.lineplot(x = range(1,1+q),y = history.history['accuracy'], label='Accuracy')
sns.lineplot(x = range(1,1+q),y = history.history['val_accuracy'], label='Val_Accuracy')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
